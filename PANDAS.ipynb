# %%
import pandas as pd
df=pd.DataFrame (
    {"a":[4,5,6,],
     "b":[7,8,9],
     "c":[10,11,12]},
      index=[1,2,3]
                )
df
# Out:
#    a  b   c
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
import pandas as pd
data=[1,2,3,4]
df=pd.DataFrame(data)
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
import pandas as pd
data=[['Alex',10],['Bob',12]]
df=pd.DataFrame(data,columns=['Name',"age"])
df
# Out:
#    Name  age
# 0  Alex   10
# 1   Bob   12

# %%
import pandas as pd
my_dataset={
    "cars":["BMV","VOLVO","FORD"],
    "passings":[3,7,2]
}
df=pd.DataFrame(my_dataset)
print(df)
# Out:
#     cars  passings
# 0    BMV         3
# 1  VOLVO         7
# 2   FORD         2

# %%
data=[{
    "a":1,"b":2
},{
    "a":5,"b":10,"c":20
}]
df=pd.DataFrame(data)
df=pd.DataFrame(data,index=["first","second"])
df1=pd.DataFrame(data,index=["first","second"],columns=["a","b","c"])
df1
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
data={
    "name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"]
}
df=pd.DataFrame(data)
address=["delhi","Bangalore","chennai","Patna"]
df["Address"]=address
df
# Out:
#      name height Qualification    Address
# 0     jai    5.1           Msc      delhi
# 1  gaurav    6.2            MA  Bangalore
# 2  princi    5.1           Msc    chennai
# 3    Anuj    5.2           Msc      Patna

# %%
data={
    "name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"]
}
df=pd.DataFrame(data)
address=["delhi","Bangalore","chennai","Patna"]
df["Address"]=address
del df["Address"]
df
# Out:
#      name height Qualification
# 0     jai    5.1           Msc
# 1  gaurav    6.2            MA
# 2  princi    5.1           Msc
# 3    Anuj    5.2           Msc

# %%
data={
    "name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"]
}
df=pd.DataFrame(data)
address=["delhi","Bangalore","chennai","Patna"]
df["Address"]=address
df.drop(columns=["Address"],inplace=True)
df.pop("Qualification")
df
# Out:
#      name height
# 0     jai    5.1
# 1  gaurav    6.2
# 2  princi    5.1
# 3    Anuj    5.2

# %%
data={
    "name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"]
}
df=pd.DataFrame(data)
address=["delhi","Bangalore","chennai","Patna"]
df["Address"]=address
df.drop(["Address"],axis=1,inplace=True)
df.pop("Qualification")
df
# Out:
#      name height
# 0     jai    5.1
# 1  gaurav    6.2
# 2  princi    5.1
# 3    Anuj    5.2

# %%
data={
    "name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"]
}
df=pd.DataFrame(data)
address=["delhi","Bangalore","chennai","Patna"]
df["Address"]=address
df.drop(["Address"],axis=1,inplace=False)
df.pop("Qualification")
df
# Out:
#      name height    Address
# 0     jai    5.1      delhi
# 1  gaurav    6.2  Bangalore
# 2  princi    5.1    chennai
# 3    Anuj    5.2      Patna

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]


}
df=pd.DataFrame(data)
df.rename(columns={"Address":"Place"},inplace=True)
df
# Out:
#      Name height Qualification      Place
# 0     jai    5.1           Msc      delhi
# 1  gaurav    6.2            MA  bangalore
# 2  princi    5.1           Msc    chennai
# 3    Anuj    5.2           Msc      patna

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]


}
df=pd.DataFrame(data)
df.drop(0,axis=0,inplace=True)
df
# Out:
#      Name height Qualification    Address
# 1  gaurav    6.2            MA  bangalore
# 2  princi    5.1           Msc    chennai
# 3    Anuj    5.2           Msc      patna

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]


}
df=pd.DataFrame(data)
df.drop(1,axis=0,inplace=True)
df
# Out:
#      Name height Qualification  Address
# 0     jai    5.1           Msc    delhi
# 2  princi    5.1           Msc  chennai
# 3    Anuj    5.2           Msc    patna

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]


}
df=pd.DataFrame(data)
print(df[["Name","Qualification"]])
# Out:
#      Name Qualification
# 0     jai           Msc
# 1  gaurav            MA
# 2  princi           Msc
# 3    Anuj           Msc

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]


}
df=pd.DataFrame(data)
df.filter(items=['Name',"Address"])
# Out:
#      Name    Address
# 0     jai      delhi
# 1  gaurav  bangalore
# 2  princi    chennai
# 3    Anuj      patna

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]


}
df=pd.DataFrame(data)
df.filter(like="eigh")
# Out:
# Name                gaurav
# height                 6.2
# Qualification           MA
# Address          bangalore
# Name: 1, dtype: object

# %%
data={
    "Name":["jai","gaurav","princi","Anuj"],
    "height":["5.1","6.2","5.1","5.2"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]


}
df=pd.DataFrame(data)
df.filter(regex="e|a",axis=1)
# Out:
#      Name height Qualification    Address
# 0     jai    5.1           Msc      delhi
# 1  gaurav    6.2            MA  bangalore
# 2  princi    5.1           Msc    chennai
# 3    Anuj    5.2           Msc      patna

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","jai"],
    "height":["5.1","6.2","5.1","5.1"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]
}
df=pd.DataFrame(data)
df = df.drop_duplicates(subset=["Name","height"],keep="last")
df
# Out:
#      Name height Qualification    Address
# 1  gaurav    6.2            MA  bangalore
# 2  princi    5.1           Msc    chennai
# 3     jai    5.1           Msc      patna

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","jai"],
    "height":["5.1","6.2","5.1","5.1"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","patna"]
}
df=pd.DataFrame(data)
df = df.drop_duplicates(subset=["Name","height"])
df
# Out:
#      Name height Qualification    Address
# 0     jai    5.1           Msc      delhi
# 1  gaurav    6.2            MA  bangalore
# 2  princi    5.1           Msc    chennai

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","jai"],
    "height":["5.1","6.2","5.1","5.1"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","delhi"]
}
df=pd.DataFrame(data)
df_sample=df.sample(n=2)
print(df_sample)
# Out:
#   Name height Qualification Address
# 0  jai    5.1           Msc   delhi
# 3  jai    5.1           Msc   delhi

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","jai"],
    "height":["5.1","6.2","5.1","5.1"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","delhi"]
}
df=pd.DataFrame(data)
df_sample=df.sample(frac=0.5)
print(df_sample)
# Out:
#      Name height Qualification    Address
# 2  princi    5.1           Msc    chennai
# 1  gaurav    6.2            MA  bangalore

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","jai"],
    "height":["5.1","6.2","5.1","5.1"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","delhi"]
}
df=pd.DataFrame(data)
df = df.drop_duplicates()
df
# Out:
#      Name height Qualification    Address
# 0     jai    5.1           Msc      delhi
# 1  gaurav    6.2            MA  bangalore
# 2  princi    5.1           Msc    chennai

# %%
import pandas as pd
data = {
    "name": ["Jai", "Princi", "Gaurav", "Anuj"],
    "age": [27, 24, 22, 32],
    "gender":["f","m","f",'m'],
    "height":["5.1","6.2","5.1","5.2"],
}
df = pd.DataFrame(data)
df=df["name"]
df
# Out:
# 0       Jai
# 1    Princi
# 2    Gaurav
# 3      Anuj
# Name: name, dtype: object

# %%
import pandas as pd
df=pd.DataFrame([[1,2],[3,4]],columns=["a","b"])
df2=pd.DataFrame([[5,6],[7,8]],columns=["a","b"])
df=pd.concat([df,df2],ignore_index=True)
df
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000]
}
df=pd.DataFrame(data)
top_salries=df.nlargest(2,columns="salary")
print(top_salries)
# Out:
#     name  age  salary
# 1    bob   25   20000
# 0  alice   24   10000

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000]
}
df=pd.DataFrame(data)
df.query('age>=25')
# Out:
#       name  age  salary
# 1      bob   25   20000
# 2  charlie   26    3000

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.query('name.str.contains("a")and age<=25')
# Out:
#     name  age  salary
# 0  alice   24   10000

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.query('gender==["M"] and age>=25')
# Out:
#   name  age  salary gender
# 1  bob   25   20000      M

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.iat[1,2]
# Out:
# 20000

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.iloc[0:3]
# Out:
#       name  age  salary gender
# 0    alice   24   10000      F
# 1      bob   25   20000      M
# 2  charlie   26    3000      F

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.iloc[0:2]
# Out:
#     name  age  salary gender
# 0  alice   24   10000      F
# 1    bob   25   20000      M

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.loc[:,['age']]
# Out:
#    age
# 0   24
# 1   25
# 2   26

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.loc[:,["name","salary"]]
# Out:
#       name  salary
# 0    alice   10000
# 1      bob   20000
# 2  charlie    3000

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df.iloc[:,0]
# Out:
# 0      alice
# 1        bob
# 2    charlie
# Name: name, dtype: object

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6,1.5]
}
df=pd.DataFrame(data)
df.iloc[0:2]
# Out:
#     name  age  salary gender
# 0  alice   24   10000      F
# 1    bob   25   20000      M

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"]
}
df=pd.DataFrame(data)
df_filtered=df[df["age"]>=25]
df_filtered
# Out:
#       name  age  salary gender
# 1      bob   25   20000      M
# 2  charlie   26    3000      F

# %%
import pandas as pd
data={
    "name":["alice","bob","charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6]
}
df=pd.DataFrame(data)
df_filtered=df[(df["age"]>=25) & (df['gender']=="M")]
df_filtered
# Out:
#   name  age  salary gender  height
# 1  bob   25   20000      M     1.7

# %%
import pandas as pd
data={
    "name":["alice","bob","Charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6]
}
df=pd.DataFrame(data)
df_filtered=df[df['name'].str.startswith(('a','C'))]
df_filtered
# Out:
#       name  age  salary gender  height
# 0    alice   24   10000      F     1.8
# 2  Charlie   26    3000      F     1.6

# %%
import pandas as pd
data={
    "name":["alice","bob","Charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6]
}
df=pd.DataFrame(data)
df.head(2)
# Out:
#     name  age  salary gender  height
# 0  alice   24   10000      F     1.8
# 1    bob   25   20000      M     1.7

# %%
import pandas as pd
data={
    "name":["alice","bob","Charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6]
}
df=pd.DataFrame(data)
df.tail(2)
# Out:
#       name  age  salary gender  height
# 1      bob   25   20000      M     1.7
# 2  Charlie   26    3000      F     1.6

# %%
import pandas as pd
data={
    "name":["alice","bob","Charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,3000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6]
}
df=pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   salary  3 non-null      int64
#  3   gender  3 non-null      object
#  4   height  3 non-null      float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 248.0+ bytes

# %%
import pandas as pd
data={
    "name":["alice","bob","Charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,30000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6]
}
df=pd.DataFrame(data)
df.describe()
# Out:
#         age   salary  height
# count   3.0      3.0    3.00
# mean   25.0  20000.0    1.70
# std     1.0  10000.0    0.10
# min    24.0  10000.0    1.60
# 25%    24.5  15000.0    1.65
# 50%    25.0  20000.0    1.70
# 75%    25.5  25000.0    1.75
# max    26.0  30000.0    1.80

# %%
import pandas as pd
data={
    "name":["alice","bob","Charlie"],
    "age":[24,25,26],
    "salary":[10000,20000,30000],
    "gender":["F","M","F"],
    "height":[1.8,1.7,1.6]
}
df=pd.DataFrame(data)
df_sorted=df.sort_values(by="age",ascending=False)
df_sorted
# Out:
#       name  age  salary gender  height
# 2  Charlie   26   30000      F     1.6
# 1      bob   25   20000      M     1.7
# 0    alice   24   10000      F     1.8

# %%
import pandas as pd
data = {'name': ['Alice', 'Bob', 'Charlie', 'Dave', 'Emily', 'Frank'],
        'gender': ['F', 'M', 'M', 'M', 'F', 'M'],
        'age': [25, 35, 40, 28, 30, 45],
        'salary': [50000, 70000, 60000, 80000, 65000, 90000]}
df=pd.DataFrame(data)
grouped=df.groupby('gender')['salary'].mean()
grouped
# Out:
# gender
# F    57500.0
# M    75000.0
# Name: salary, dtype: float64

# %%
import pandas as pd
data={
    "Name":["jai","gaurav","princi","jai"],
    "height":["5.1","6.2","5.1","5.1"],
    "Qualification":["Msc","MA","Msc","Msc"],
    "Address":["delhi","bangalore","chennai","delhi"],
    "salary":[50000, 70000, 60000, 80000],
    "age":[18,17,16,15]
}
df=pd.DataFrame(data)
grouped=df.groupby(by='age')
